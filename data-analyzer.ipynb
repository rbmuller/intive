# %% [markdown]
# ## Jupyter Notebook for Data Analysis
#
# ### This notebook is intended to be used for data analysis, as it's a jupyter nb, it runs iteratively, being able to easily plot data and visualize it

# %%
#Imports
from helpers.data_cleaner import GetCleanData, create_spark_session

# %%
# Initilize Spark Session and ingest data 
spark = create_spark_session()

df = spark.read.option("header", "true").csv("data/sales_data.csv")

# %%
# Display first 50 rows
df.show(50)

# %%
# Try yourself
